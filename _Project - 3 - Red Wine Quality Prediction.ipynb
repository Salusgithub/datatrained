# %%
#import libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# read file
df = pd.read_csv("E:\projects\wine.csv")
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# describe

df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
df.shape
# Out:
# (1599, 12)

# %%
print("Total rows: ",df.shape[0])
print("Total columns: ",df.shape[1])
# Out:
# Total rows:  1599
# Total columns:  12

# %%
df.columns.tolist()
# Out:
# ['fixed acidity',
#  'volatile acidity',
#  'citric acid',
#  'residual sugar',
#  'chlorides',
#  'free sulfur dioxide',
#  'total sulfur dioxide',
#  'density',
#  'pH',
#  'sulphates',
#  'alcohol',
#  'quality']

# %%
df.info
# Out:
# <bound method DataFrame.info of       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# no Categorical column

# %%
#check null values
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
#Checking missing data using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# Dataset Visualization
sns.pairplot(df)

# %%
#plotting response variable
sns.countplot(df['quality'])
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
#Checking the data points available in quality column and set threshold to classify if good wine or not.
df['quality'].value_counts()
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
set(df['quality'])
# Out:
# {3, 4, 5, 6, 7, 8}

# %%
df['check']=1
for i in range(len(df)):
    if df['quality'][i]<7:
        df['check'][i]=0
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
set(df[df['check']==1]['quality'])
# Out:
# {7, 8}

# %%
set(df[df['check']==0]['quality'])
# Out:
# {3, 4, 5, 6}

# %%
df['check'].value_counts()
# Out:
# 0    1382
# 1     217
# Name: check, dtype: int64

# %%
df.shape
# Out:
# (1599, 13)

# %%
df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# check                     int64
# dtype: object

# %%
print('good wines are:',df['check'].value_counts()[0])
print('Number of good wines are:',df['check'].value_counts()[1])
print('Imbalanced dataset' if df['check'].value_counts()[0]!=df['check'].value_counts()[1] else 'Balanced dataset')
# Out:
# good wines are: 1382
# Number of good wines are: 217
# Imbalanced dataset

# %%
plt.figure(figsize=[5,5])
df['check'].value_counts().plot(kind='bar')
plt.xlabel("class")
plt.ylabel('value counts')
plt.title('Number of good and not good wine')
plt.grid()

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(df[['fixed acidity','volatile acidity','citric acid','residual sugar','chlorides','free sulfur dioxide','total sulfur dioxide','density','pH','sulphates','alcohol']], df[['check']])

y.value_counts()
# Out:
# check
# 0        1382
# 1        1382
# dtype: int64

# %%
df_new = x.copy()
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 2759       7.424294          0.404219     0.263710        2.500000   0.066900
# 2760       9.002945          0.374994     0.408822        2.376443   0.101940
# 2761       6.841088          0.760755     0.044109        2.609592   0.074411
# 2762       7.189603          0.536430     0.150096        5.099043   0.060731
# 2763       9.208261          0.427596     0.486843        4.369913   0.096684
#
# ...

# %%
df_new['check']=y
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 2759       7.424294          0.404219     0.263710        2.500000   0.066900
# 2760       9.002945          0.374994     0.408822        2.376443   0.101940
# 2761       6.841088          0.760755     0.044109        2.609592   0.074411
# 2762       7.189603          0.536430     0.150096        5.099043   0.060731
# 2763       9.208261          0.427596     0.486843        4.369913   0.096684
#
# ...

# %%
#Correlation
df_new.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.301883     0.718833
# volatile acidity          -0.301883          1.000000    -0.594350
# citric acid                0.718833         -0.594350     1.000000
# residual sugar             0.148442          0.007130     0.174980
# chlorides                  0.110514          0.115104     0.153899
# free sulfur dioxide       -0.160431          0.046604    -0.081607
# total sulfur dioxide      -0.168791          0.149659    -0.048772
# density                    0.660004          0.085017     0.336916
# pH                        -0.716767          0.282039    -0.605240
# sulphates                  0.212641         -0.322945     0.331874
# alcohol                   -0.079050         -0.300501     0.166946
# check                      0.170343         -0.437380     0.321789
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
#Correlation using Heatmap:
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot = True, linewidths = 0.5,cmap ='gist_earth')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Correlation Result
#
# Positively correlated columns are: alcohol, citric acid, sulphates, fixed acidity, residual sugar
# Negatively correlated columns are: pH, total sulfur dioxide, chlorides, total sulfur dioxide, density, volatile acidity

# %%
plt.figure(figsize=(22,7))
df.corr()['check'].sort_values(ascending=False).drop(['check','quality']).plot(kind='bar',color='c')
plt.xlabel('feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# columns pH , free sulfur dioxide , chlorides , total sulfur dioxide , density , volatile acidity are having negative correlation.

# %%
sns.barplot(x="check",y="alcohol",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="sulphates",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="pH",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="density",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="total sulfur dioxide",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="free sulfur dioxide",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="free sulfur dioxide",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="chlorides",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="residual sugar",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="citric acid",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="volatile acidity",data=df_new)
plt.show()

# %%
sns.barplot(x="check",y="fixed acidity",data=df_new)
plt.show()

# %%
#PH and density columns values data are not able to distinguish between classes hence to be dropped
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(df_new.drop(['pH','density'],axis=1).corr(),annot=True,ax=ax)
# Out:
# <AxesSubplot:>

# %%
df=df_new.drop(['pH','density'],axis=1)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 2759       7.424294          0.404219     0.263710        2.500000   0.066900
# 2760       9.002945          0.374994     0.408822        2.376443   0.101940
# 2761       6.841088          0.760755     0.044109        2.609592   0.074411
# 2762       7.189603          0.536430     0.150096        5.099043   0.060731
# 2763       9.208261          0.427596     0.486843        4.369913   0.096684
#
# ...

# %%
#Describing Datasets
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    2764.000000       2764.000000  2764.000000     2764.000000
# mean        8.534377          0.472491     0.316237        2.569198
# std         1.747061          0.170435     0.192180        1.286181
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.275943          0.340000     0.150000        1.944449
# 50%         8.273155          0.436054     0.331295        2.200000
# 75%         9.590047          0.585626     0.461367        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide    sulphates  \
# count  2764.000000          2764.000000           2764.000000  2764.000000
# mean      0.082136            15.060209             41.000219     0.694177
# std       0.038675            10.324038             31.471550     0.153361
# ...

# %%
#Heatmap
plt.figure(figsize=(10,12))
sns.heatmap(round(df.describe()[1:].transpose(),2),linewidth = 2, annot = True, fmt = 'f')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("Variable Summary")
plt.show()

# %% [markdown]
# From the above plotting we are determining mean, standard deviation, minimum and maximum value of each column. It helps us further in data cleaning.
#
# Total Number of rows in the datasets:
#
# 2764 rows 10 columns
#
# fixed acidity: Mean=8.586073, std=1.783450, max_value = 15.900000, min_value=4.600000
#
# volatile acidity:
#
# Mean=0.472189, std=0.168914, max_value=1.580000, min_value=0.120000
#
# citric acid: Mean= 0.320374, std=0.195393, max_value=1.000000, min_value=0.000000
#
# residual sugar: Mean=2.592237, std=1.300169, max_value=15.500000, min_value=0.900000
#
# chlorides: Mean=0.082659, std=0.039095, max_value=0.611000, min_value=0.012000
#
# free sulfur dioxide: Mean=14.927737, std=10.398465, max_value=72.000000, min_value=1.000000
#
# total sulfur dioxide: Mean=41.093414, std=32.221340, max_value=289.000000, min_value=6.000000
#
# sulphates: Mean=0.695581, std=0.156195, max_value=2.000000, min_value= 0.330000
#
# alcohol: Mean=10.888612, std=1.128280, max_value=14.900000, min_value=8.400000
#
# classify: Mean=0.50000, std=0.50009, max_value=1.00000, min_value = 0.00000

# %%
#Checking for Outliers
col_list = df.columns.values
ncol = 15
nrows = 15
plt.figure(figsize=(30,80))
for i in range(0, len(col_list)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[col_list[i]],color = 'cyan', orient='h')
    plt.tight_layout()

# %%
#Remove outlier using zscore technique:
import scipy.stats as stats
from scipy.stats import zscore
z_scr=zscore(df)
print(df.shape)
df_new=df.loc[(abs(z_scr)<3).all(axis=1)]
print(df_new.shape)
# Out:
# (2764, 10)
# (2565, 10)

# %%
#Data loss percent:
((2764-2565)/2764)*100
# Out:
# 7.199710564399421

# %%
#outliers removed as there is less than 10% data loss. now cross check
col_list = df_new.columns.values
ncol = 15
nrows = 15
plt.figure(figsize=(30,80))
for i in range(0, len(col_list)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df_new[col_list[i]],color = 'cyan', orient='h')
    plt.tight_layout()

# %%
#still outlier exists. use iqr to try to remove
Q1 = df.quantile(q=.25)
Q3 = df.quantile(q=.75)
IQR = df.apply(stats.iqr)

#only keep rows in dataframe that have values within 1.5*IQR of Q1 and Q3
data_clean = df[~((df < (Q1-1.5*IQR)) | (df > (Q3+1.5*IQR))).any(axis=1)]

#find how many rows are left in the dataframe 
data_clean.shape
# Out:
# (2124, 10)

# %%
((2764-2124)/2764)*100
# Out:
# 23.154848046309695

# %%
# cant use iqr, as data loss more than 10%, use zscore output data as it was able to remove some outlier
z_scr=zscore(df_new)
print(df_new.shape)
df1=df_new.loc[(abs(z_scr)<3).all(axis=1)]
print(df1.shape)
# Out:
# (2565, 10)
# (2361, 10)

# %%
((2764-2361)/2764)*100
# Out:
# 14.580318379160637

# %%
#further applying of zscore creates a data loss of more 10% hence use dff_new
df_new
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0          7.400000          0.700000     0.000000        1.900000   0.076000
# 1          7.800000          0.880000     0.000000        2.600000   0.098000
# 2          7.800000          0.760000     0.040000        2.300000   0.092000
# 3         11.200000          0.280000     0.560000        1.900000   0.075000
# 4          7.400000          0.700000     0.000000        1.900000   0.076000
# ...             ...               ...          ...             ...        ...
# 2759       7.424294          0.404219     0.263710        2.500000   0.066900
# 2760       9.002945          0.374994     0.408822        2.376443   0.101940
# 2761       6.841088          0.760755     0.044109        2.609592   0.074411
# 2762       7.189603          0.536430     0.150096        5.099043   0.060731
# 2763       9.208261          0.427596     0.486843        4.369913   0.096684
#
# ...

# %%
#check if dataset still balanced or not
df_new['check'].value_counts()
# Out:
# 1    1328
# 0    1237
# Name: check, dtype: int64

# %%
#checking all the distribution plot
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['fixed acidity'],label='1')
sns.distplot(bad['fixed acidity'],label='0')
# Out:
# <AxesSubplot:xlabel='fixed acidity', ylabel='Density'>

# %%
#The presence of fixed acidity in good wine and bad wine quality differs and the distribution of the data seems to be biased.

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['volatile acidity'],label='1')
sns.distplot(bad['volatile acidity'],label='0')
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Density'>

# %%
#presence of volatile acidity in good wine and bad wine quality also differs and the distribution of the data seems to be biased.

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['citric acid'],label='1')
sns.distplot(bad['citric acid'],label='0')
# Out:
# <AxesSubplot:xlabel='citric acid', ylabel='Density'>

# %%
#The Data of the Column "citric acid" is not normalised. The building blocks is out of normalised curve.

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['residual sugar'],label='1')
sns.distplot(bad['residual sugar'],label='0')
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='Density'>

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['chlorides'],label='1')
sns.distplot(bad['chlorides'],label='0')
# Out:
# <AxesSubplot:xlabel='chlorides', ylabel='Density'>

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['free sulfur dioxide'],label='1')
sns.distplot(bad['free sulfur dioxide'],label='0')
# Out:
# <AxesSubplot:xlabel='free sulfur dioxide', ylabel='Density'>

# %%
#The Data of the Column "free sulfur dioxide" is not normalised. The building blocks is out of normalised curve and it is positively skewed

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['total sulfur dioxide'],label='1')
sns.distplot(bad['total sulfur dioxide'],label='0')
# Out:
# <AxesSubplot:xlabel='total sulfur dioxide', ylabel='Density'>

# %%
#The data of the column "total sulfur dioxide" is not normalised, the data is biased.

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['sulphates'],label='1')
sns.distplot(bad['sulphates'],label='0')
# Out:
# <AxesSubplot:xlabel='sulphates', ylabel='Density'>

# %%
good=df_new[df_new['check']==1]
bad=df_new[df_new['check']==0]
sns.distplot(good['alcohol'],label='1')
sns.distplot(bad['alcohol'],label='0')
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Density'>

# %%
#The presence of alcohol in good wine and bad wine quality are highly differentiates and the distribution of the data seems to be biased.

# %% [markdown]
# ## Feature scaling:

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(df_new.drop(['check'],axis=1))
fx=sc.transform(df_new.drop(['check'],axis=1))
x=pd.DataFrame(fx,columns=df_new.drop(['check'],axis=1).columns)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0         -0.653064          1.483149    -1.643554       -0.602330  -0.096524
# 1         -0.416260          2.620620    -1.643554        0.164879   1.084925
# 2         -0.416260          1.862306    -1.432169       -0.163925   0.762712
# 3          1.596570         -1.170948     1.315843       -0.602330  -0.150226
# 4         -0.653064          1.483149    -1.643554       -0.602330  -0.096524
# ...             ...               ...          ...             ...        ...
# 2560      -0.638681         -0.385976    -0.249944        0.055277  -0.585203
# 2561       0.295894         -0.570654     0.516923       -0.080143   1.296508
# 2562      -0.983945          1.867079    -1.410455        0.175392  -0.181863
# 2563      -0.777620          0.449502    -0.850353        2.903861  -0.916529
# 2564       0.417443         -0.238250     0.929238        2.104726   1.014271
#
# ...

# %%
#check for biasing in data
print(x.skew())
# Out:
# fixed acidity           0.531248
# volatile acidity        0.621092
# citric acid            -0.051708
# residual sugar          2.282147
# chlorides               1.313907
# free sulfur dioxide     1.067693
# total sulfur dioxide    1.281547
# sulphates               0.350262
# alcohol                 0.230794
# dtype: float64

# %%
# Number of features having skewness more than 0.55 
print(len(x.skew().loc[x.skew()>0.55]))
# Out:
# 5

# %%
# remove biasing
for index in x.skew().index:
    if x.skew().loc[index] >0.55:
        x[index]=np.cbrt(x[index])

# %%
#lets again check the skewness
print(x.skew())
print()
print(len(x.skew().loc[x.skew()>0.55]))# Number of features having skewness more than 0.55
# Out:
# fixed acidity           0.531248
# volatile acidity        0.258619
# citric acid            -0.051708
# residual sugar          0.862467
# chlorides               0.208809
# free sulfur dioxide     0.449745
# total sulfur dioxide    0.501878
# sulphates               0.350262
# alcohol                 0.230794
# dtype: float64
#
# 1

# %%
#check if columns can be further reduced
from sklearn.decomposition import PCA
for i in range(2,10):
    pca = PCA(n_components=i)
    principalComponents = pca.fit_transform(x)
    plt.figure()
    plt.plot(np.cumsum(pca.explained_variance_ratio_))
    plt.xlabel("number of components")
    plt.ylabel('Variance(%)') #for each component
    plt.title('Explained Variance')
    plt.show()
    print(i,sum(pca.explained_variance_ratio_))
# Out:
# 2 0.5160499218987699
# 3 0.6851678201959014
# 4 0.7779013220962484
# 5 0.8602942191173804
# 6 0.9136981161136749
# 7 0.9583769577055501
# 8 0.9825509635586831
# 9 1.0

# %% [markdown]
# so, the above plotting describes that around 95% of the variance is being explained by 7 components.

# %%
pca = PCA(n_components=7)
principalComponents = pca.fit_transform(x)
principalComponents
# Out:
# array([[-2.31033548, -0.28783529, -1.4238702 , ...,  0.43875469,
#         -0.57824354, -0.08261459],
#        [-2.37112236, -1.28477064,  1.0720536 , ...,  0.9022389 ,
#         -0.12353559, -0.13390453],
#        [-2.2519405 , -1.04715426,  0.43745433, ...,  0.82682929,
#          0.26574334,  0.33240276],
#        ...,
#        [-1.20780816,  1.43367417,  0.40403634, ...,  1.1714141 ,
#         -0.78458557,  0.01346233],
#        [-0.84376596,  0.55339833, -1.04594703, ..., -0.01373386,
#         -1.38037962, -1.01532583],
#        [ 1.61856658, -0.36100526, -1.05929098, ..., -0.74874984,
#          0.57378344, -0.39401261]])

# %%
y=df_new['check'].values
y
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int64)

# %% [markdown]
# ## code to find best random state for train test split

# %%
from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

# %%
def besttrain(model,x,y):
    random=0
    score=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,random_state = i,test_size=0.20,stratify=y,shuffle=True)
        model.fit(x_train,y_train)
        tmp=roc_auc_score(y_test,model.predict(x_test))
        #print(i,tmp)
        if tmp>score:
            score=tmp
            random=i
    print("maximum roc_auc_score is at random state :",random," and it is :",score)

# %% [markdown]
# ## code to find best classifier model among all

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import Lasso
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import LassoLars
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score,roc_curve

# %%
models=[LogisticRegression(),DecisionTreeClassifier(),KNeighborsClassifier(),RandomForestClassifier(),SVC(),RidgeClassifier(),
        BaggingClassifier(),GradientBoostingClassifier(),Lasso(),ElasticNet(),LassoLars(),BayesianRidge(),SGDClassifier()]

# %%
best_model=0
best_score=0
score=0
for i in models:
    scores=cross_val_score(i,principalComponents,y,cv=5,scoring='roc_auc')
    score=np.mean(scores)
    if score>best_score:
        best_score=score
        best_model=i
print(best_model)
print(best_score)
print(np.std(scores))
# Out:
# RandomForestClassifier()
# 0.9641297027822168
# 0.04767155480109741

# %%
#Fine-tuning model using hyper parameter
parameters={"n_estimators":[10,100,500],'criterion':['gini', 'entropy'],'max_features':['auto', 'sqrt', 'log2']}
clf = GridSearchCV(RandomForestClassifier(), parameters, cv=5,scoring="roc_auc")
clf.fit(principalComponents,y)
clf.best_params_
# Out:
# {'criterion': 'gini', 'max_features': 'auto', 'n_estimators': 500}

# %%
#Finding best random state
besttrain(RandomForestClassifier(n_estimators=500,criterion='gini',max_features='auto'),principalComponents,y)
# Out:
# maximum roc_auc_score is at random state : 50  and it is : 0.9489589358010411

# %%
#Finalize model train and fitting
x_train, x_test, y_train, y_test = train_test_split(principalComponents, y,random_state = 45,test_size=0.20,stratify=y)
rf_clf=RandomForestClassifier(n_estimators=500,criterion='gini',max_features='sqrt')
rf_clf.fit(x_train,y_train)
y_pred=rf_clf.predict(x_test)

# %%
#Find all metrics required to evaluate the model
print("Confusion matrix \n",confusion_matrix(y_test,y_pred))
print("f1 score is : ",f1_score(y_test,y_pred))
print("classification report \n",classification_report(y_test,y_pred))
print("AUC ROC Score: ",roc_auc_score(y_test,y_pred))
scores=cross_val_score(i,principalComponents,y,cv=5,scoring='roc_auc')
score=np.mean(scores)
std=np.std(scores)
print('CV mean',score)
print('std:',std)
# Out:
# Confusion matrix
#  [[220  27]
#  [ 10 256]]
# f1 score is :  0.9326047358834243
# classification report
#                precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92       247
#            1       0.90      0.96      0.93       266
#
#     accuracy                           0.93       513
#    macro avg       0.93      0.93      0.93       513
# weighted avg       0.93      0.93      0.93       513
#
# AUC ROC Score:  0.9265471370734528
# CV mean 0.8444000765328719
# std: 0.05424379512293375

# %%
#AUC ROC curve of model
fpr, tpr, threshold = roc_curve(y_test,y_pred)
auc = roc_auc_score(y_test,y_pred)
plt.plot(fpr, tpr, color ='orange', label ='ROC')
plt.plot([0, 1], [0, 1], color='darkblue', linestyle='--', label ='ROC curve (area = %0.3f)'% auc)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
#Save model
import joblib
joblib.dump(rf_clf, 'wine.obj')
# Out:
# ['wine.obj']

# %%
import numpy as np
loadmodel = joblib.load('wine.obj')

a = np.array(y_test)
predicted = np.array(loadmodel.predict(x_test))
df_com = pd.DataFrame({"Original":a,"Predicted":predicted},index= range(len(a)))
df_com
# Out:
#      Original  Predicted
# 0           1          1
# 1           0          0
# 2           0          0
# 3           1          1
# 4           1          1
# ..        ...        ...
# 508         1          1
# 509         1          1
# 510         0          0
# 511         1          1
# 512         0          0
#
# [513 rows x 2 columns]
