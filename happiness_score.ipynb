# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

data=pd.read_csv("C:\\Users\\geopt\\Downloads\\happiness_score.csv", sep=',', encoding='latin-1')

data
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
g = sns.pairplot(data)
g.fig.subplots_adjust(top= 0.9);

# %%
econ_happiness = ['Happiness Score','Economy (GDP per Capita)']

econ_corr = data[econ_happiness]

econ_corr.corr()
# Out:
#                           Happiness Score  Economy (GDP per Capita)
# Happiness Score                  1.000000                  0.780966
# Economy (GDP per Capita)         0.780966                  1.000000

# %%
sns.regplot(data = econ_corr, x = 'Happiness Score', y = 'Economy (GDP per Capita)').set_title("Happiness score vs Economy")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Economy')

# %%
fam_happiness = ['Happiness Score','Family']

fam_corr = data[fam_happiness]

fam_corr.corr()
# Out:
#                  Happiness Score    Family
# Happiness Score         1.000000  0.740605
# Family                  0.740605  1.000000

# %%
sns.regplot(data = fam_corr, x = 'Happiness Score', y = 'Family').set_title("Happiness score vs Family")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Family')

# %%
health_happiness = ['Health (Life Expectancy)','Happiness Score']

health_corr = data[health_happiness]

health_corr.corr()
# Out:
#                           Health (Life Expectancy)  Happiness Score
# Health (Life Expectancy)                    1.0000           0.7242
# Happiness Score                             0.7242           1.0000

# %%
sns.regplot(data = health_corr, x = 'Happiness Score', y = 'Health (Life Expectancy)').set_title("Happiness score vs Health")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Health')

# %%
freedom_happiness = ['Freedom', 'Happiness Score']

freedom_corr = data[freedom_happiness]

freedom_corr.corr()
# Out:
#                   Freedom  Happiness Score
# Freedom          1.000000         0.568211
# Happiness Score  0.568211         1.000000

# %%
sns.regplot(data = freedom_corr, x = 'Happiness Score', y = 'Freedom').set_title("Happiness score vs Freedom")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Freedom')

# %%
trust_happiness = ['Trust (Government Corruption)','Happiness Score']

trust_corr = data[trust_happiness]

trust_corr.corr()
# Out:
#                                Trust (Government Corruption)  Happiness Score
# Trust (Government Corruption)                       1.000000         0.395199
# Happiness Score                                     0.395199         1.000000

# %%
sns.regplot(data = trust_corr, x = 'Happiness Score', y = 'Trust (Government Corruption)').set_title("Happiness score vs Gov. Corruption")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Gov. Corruption')

# %%
gen_happiness = ['Generosity','Happiness Score']

gen_corr = data[gen_happiness]

gen_corr.corr()
# Out:
#                  Generosity  Happiness Score
# Generosity         1.000000         0.180319
# Happiness Score    0.180319         1.000000

# %%
sns.regplot(data = gen_corr, x = 'Happiness Score', y = 'Generosity').set_title("Happiness score vs Generosity")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Generosity')

# %%
dyst_happiness = ['Dystopia Residual','Happiness Score']

dyst_corr = data[dyst_happiness]

dyst_corr.corr()
# Out:
#                    Dystopia Residual  Happiness Score
# Dystopia Residual           1.000000         0.530474
# Happiness Score             0.530474         1.000000

# %%
sns.regplot(data = dyst_corr, x = 'Happiness Score', y = 'Dystopia Residual').set_title("Happiness score vs Generosity")
# Out:
# Text(0.5, 1.0, 'Happiness score vs Generosity')
